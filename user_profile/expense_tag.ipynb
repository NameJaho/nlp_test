# %%
import warnings
from user_profile.profile_service import *
warnings.filterwarnings('ignore')

INPUT_FILE = 'data/xhs-T1-40W.csv'
CONFIG_FILE = 'config/config.yaml'
DOMAIN = 'EXPENSE'

# %%
# load config
config = load_config(CONFIG_FILE)

global_nickname_blacklist = get_global_nickname_blacklist(config)
domain_nickname_blacklist = get_domain_nicknames_blacklist(config, domain=DOMAIN)

domain_content_whitelist = get_content_whitelist(config, domain=DOMAIN)
domain_content_blacklist = get_content_blacklist(config, domain=DOMAIN)

# %%
# load data then remove global biz user
df = load_data(INPUT_FILE)
df = remove_biz_user(df, global_nickname_blacklist)
df = remove_biz_user(df, domain_nickname_blacklist)
len(df)
# Out:
# 225872

# %%
# apm ole
# '卡地亚','Cartier','宝格丽','纪梵希','Givenchy','爱马仕','香奈儿','Hermes'
# '花呗','蜜雪冰城','正新鸡排','华莱士','shake shack'
#,'兰亭永','好酒好蔡','焯跃料理','Anise','植庭寿司','Ensue','鮨一'
#'合租','招室友'
#'文华东方','宝格丽酒店'
# '大董','米其林',

# %%
df_filtered = filter_by_score(df, domain_content_whitelist, domain_content_blacklist, 1)
df_user = group_by_user(df_filtered)
print(f'expense - #posts:{len(df_filtered)}, #users: {len(df_user)}')
# Out:
# expense - #posts:2511, #users: 1315

# %%
nicknames = get_unique_nicknames(df_filtered)
print(nicknames[0:1000])
# Out:
# ['虞小白' '白白的牙呀' '暴小走' 'Sis玩转上迪' '人生海海' '雪山一只狐' '黄慧 Amy' '饼哥来吃饭' '透明的象'
#  '麦乐小猫块' '夏天的忧伤�' '阿鱼的开心磁场' '六棵柳树扭六扭' '啾咪' 'Merry团酱�' 'HeSheIt_101010'
#  '荟集生活' '扬帆俄罗斯一手送签' '喜欢大橙子' '薯条�' '�呢' 'MlleS' '寻找阳光的大男孩' 'koko在努力哦'
#  'Colorful�伊雨尘�' '丢丢' 'XXXiao' 'DDnt' 'michelleyu' 'cici' '�酱' '无敌大嘴嘴�'
#  'Ama' '小小小丸子吗' 'momo' '番茄酱' '甄铃木子' '嘉嘉也是宝宝' '小可心' '每周都有8天不想上班'
#  '爔爻(xiyao)' '佐红加拿大' 'Viv with Nothing' 'Max' '�Seawave钦然' '麻酱的' 'Michael'
#  '佳音' 'Natalie�' '小红薯' '双子爱水瓶' 'Amao' '集美汇阿豪' '先先曾�' '山楂猪头' '铃儿响叮当'
#  '小红薯6485A44B' '蒨嫺様、' '还是那颗baby�' 'Better Me' '百思不得其姐' '用户726336771' '糖衣'
#  'kiko loli' 'Hello柠心儿' '音之島' 'omom' 'Mangonnn' '�果蛋儿��每一天�'
#  'Antetokounmp0' 'aiu' '艾莉娜云' '花花必卷' '四分之一橙子�' '小小Suki�' '野橘橘�' 'wawa8191'
#  'mandyk' '果果果子' '星桐Z�' 'Pinkvy_' '阿饼饼' '事已至此睡觉' '一匹孤狼' '讨厌吃吃茄子' '秀场T台宝妈'
#  '格格小巫' '西洋镜' '桃桃爱绘本' '一只酸菜鱼' '嘀嗒�' '干饭选手又饿了' '小红薯6488D9B8' 'UK司徒' '亚朵员工'
#  '�EVA��' '小红薯65E34586' '雪顶奶昔' '桃叽�' '幸德瑞丫' '小番薯涓涓' 'Cathay' 'yuka_酱' '0'
#  'ohlala文奕' '塞巴斯蒂安的女友' 'May的自装日记' 'momozizi' '小鹿鹿要求是' 'Katie_qiiiiii'
#  '达步溜星' '张筱璇' '鱼在水中游' 'misfitsss \ue13d' '袁sir聊EB5' '明天你好�' '李白不作诗'
#  '一天只登陆n次的账号' '已经是一个大人了' '爱笑的薇薇' 'yami' '昕之' '玮彤' '傲娇的小玫瑰' '不要被人看到的小号'
#  '向日葵栖息地' '纯美少女biubiu' '小红薯65ADCC4A' 'Judyone' 'tree�' '巴拉巴拉小魔仙安小宁'
#  'Healer，' 'Luna_兔�' '�Helen�' '泡泡糖' '阿旭同学' 'Miki' 'lucifer'
#  'charlottezhuang' '也也' '胖虎大阿妹' '青争鱼' '冰壶秋月无敌' '西大门小猪猪' 'Claireleo' '无敌虎爸'
#  '大圆子' 'Zack_Wang' 'Nicole每天都要开心呢�' '奶茶三分甜' 'Beckyyyyy' 'Angelagg'
#  '“�”小果✨✨' '3XI' 'MasonsMami' '女开小开' '是567呀～' '签签如意' 'MOMO' '玉木木'
#  '复旦中山陆南杭' '小鱼打小怪兽' 'kkrii' '大川Visa' 'A doeS站西源头 老凡' '徐萌太甜了' '三生' '悠悠'
#  '瓦努生活日记' '酷的飞起' '菲律宾签-沐林' '同款点这里' '婆婆嘴' '还是那个追风少年' '奋斗中的大魔头' '河马君Yuri'
#  'ChrisQ' 'sssea' '大猫＿Alicia' '黑眼圈费费' '大橘为重' '羊驼一家门' '好好吃饭认真减肥' 'WENNY19'
#  '莫冉❤' '雅琪旅游小达人儿' '噢妮酱酱' 'M小朋友' '第一眼' 'angelaqiu123' '双果妈咪�'
#  '努力无效但可以浪费时间！' '鼠鼠我呀' '乖巧和可爱' '妍妍82' '�阿尹' '风中的美少女战士' '橘子糯米粥' '14pm手机壳大户'
#  'Neilten Zhao' '苏打珏气' '小8大魔王' '柑橘味的栀子花' '雕_雕小姐' '�' '归去来兮' '神の双生子'
#  '小北和圈圈' '王嘉尔老婆' '猫妖' '宋宋' 'Miss i' '陈牛牛�' '小兔子妈妈' '江南小智' '艾米小姐' '转多雨的小跑腿'
#  '小鱼蛋' 'feibi' '三七' 'Kay' '黄小邪' 'PLJJ' '我想出去春游' '扎哥说移美' '花舞精灵' '果果酱�'
#  '妹妹的土豆妈妈' 'Rena是石太太吖' 'Zhenger' '闷声大发财' '卒卒的妈' 'Rebecca Hu' 'QQianian'
#  '�一闪一闪小星星�' 'CrazyAlevel' '王律不打烊' '爱睡觉de大小白' '人生百态' '盒马下午茶' '五哥教融房' '安妈'
#  '皮皮�' '香蕉船上的海綿寶寶�' '一只羊�' '哈库呐玛塔塔' 'David' '行走的恋恋✨' '遨悠畅居RoamTravel'
#  'Alien' '辉盛好车' 'Livian' 'cacooca白胖儿' '咕噜哐啷咕噜哐' 'Bang bang bang' '开心快乐'
#  '绒绒的茸茸' 'lk牛妞妈' 'nana0735' 'momomao' '小强叔' '小菇凉大滑板' 'LzLz0214' '天初晴w艾'
#  'isssland' 'Candice-君君' 'Dufanxi' 'CHEER-L-Y' '湛湛拉灯' '浅浅酱♪' '少女六'
#  '红菇凉大女王' '非遗Plus' '哎呦喂小破孩' 'KunChen-做个闲人' '小猫头' 'kingkingchan' '小丸子'
#  'piggybear' 'Nicky_wk' '铂典POLVCDG' '海陵岛游艇出海思思子�' '躺着不想起的懒宅' '柳宿增十' '糖粥粥'
#  '小黑不黑' '小红薯656E1159' 'Emily' '今夕是何夕988' '�酒红色高跟鞋�' '卡崩拉卡' 'zz' '美少女壮士'
#  'Shivvo' 'eye4' '小mo' '隐匿' '成长会进化吗' '小椰子coconut�' '朴彩月' '是张天呐呀�'
#  'Dream121991' 'Herman' 'carloine' 'stehom' 'ArissaLi' 'Cicilalala' '饭团焗饭'
#  '家有俩娃的修行' 'Lexi' '慢慢想退休' '戴着小头盔' 'Cynth1aaaaaa_' '筱冉丫' '�Panda' '羊小排爱吃肉'
#  '�老年痴呆' 'Celine-lsl' '小公子' '小呵呵' '万能菇菇子�' 'angela_0310' '百里须臾' '路人K'
#  '小刘刘KK' '小趴菜一定成研' '春和景明' '瑾' '娜小签' '曼鱼别吃了' '卖女孩的小火柴' '小芝士' '酥哥' '大象�'
#  '尹乔伊' '随便瞧瞧' '甘蔗不能啃' 'ᅠᅠᅠcarmen' '��清澈明朗的小日子��' '非洲通行' '铭翊瑜伽'
#  '自由先生Mr. Liberty' 'Miss-LQian' 'Alice小猫咪（孕妇版）' '小珊' 'mandy （护肤号）'
#  'dongyu17' 'Feng' '�没我淘' 'MO墨MO' '南壹UNA' '宜欢玺' '我是Luna_' 'ALive' '瑞秋'
#  'babedoll' '沙了个沙' '嗯啊' '考小尼' 'JINGJING' 'JannyJohn' '_Albert'
#  '小红薯65E87838' '洁洁愉' '东方夜糖' '张开心就好' 'bonnie' '大头瑶瑶' '#NAME?' '诡计多端的穷男人'
#  '港姐深谈' '� ‿ �蘑菇云��' '想吃小蛋糕�' '是绿洲的白日梦' '今日外卖吃什么' '香酚之家' '王胖胖��' '迪达拉'
#  'Lrina宝宝' '小笼包金融街分包' '白云保时捷_欧生｜tyler' '黑妞妞' '晶静 � �' '亲爱的小宇宙'
#  '用户NIDEBABA' 'Da蒙哥' '碎月雅集' '小璐璐' '风风bb' '一只羊1111' 'XXXNaNa' '请注意倒车'
#  '小兔子1204' 'mmmikiii' '�biubiubiuZ�' '天天天' '京东宠物' '喵喵喵喵喵喵喵' '哦吼～' '一只小可爱'
#  '小五姑奶奶' 'Y.un' 'Moon' '绾绾bella' '小�的理想生活' '好运来' '安安凡的白' '不知名博主dada' '豆儿'
#  '�～果smiling' 'Uoou' '愤怒的小鸟子�' '_c__c__c_' 'Guyue' '三美元的Happy Map' '大元圆圆的'
#  'YU-M' 'Alisa～' 'Violet' 'lynn琳Lin- SH' '大壮闯水贝' 'Andrew说香港身份' 'bobolsh'
#  '骑妮仔的小次郎！' '泰迪糖糖' '橘子精' '瑶瑶领先✨' 'Cassie_（认真减肥版）' '多多的大树洞' '空心小黑兔' '小渊渊~'
#  '中教服' '不如当为姑娘你抚琴' '小树�' 'Francessu' 'newyvonne' '一朵小花花' '叶子营业中' '❄慕琰'
#  'Rachel' 'lsy' '木子小的新生活' '丸丸豆' 'daily_daily' '小雨哗啦啦' '阝可♥笛笛笛笛♥' '_小白先生'
#  '顺顺要诸事皆如意' 'gi总在曼谷' '睡着了我就不困了��' '吃土豆长大的马铃薯' '妮可沁小屋 nmm33644'
#  '小红薯661DEDAC' '泡芙泡泡' '火星翻译' '古里CC' 'bearer' '叶雨星' '猫女王H2' '是思绮啊' '美丽温柔'
#  'Jessie是不是太普通' '鹿子�' '郑紫紫' '咪仙人' '潘妮' 'vivian' '北茗隽王' '我不是喜宝' 'Angelina�'
#  '格格鲁' '七七子来了' '阳崽' '冬' '亭亭子呀（是本人）' '往事随风' '小甜橙� TAYAMA' 'Caroline'
#  '惟觅MICE商旅会奖' '甜酒的画画本' '贝展超牛' '猪猪开心果' 'haleth' '�小汽水。' '�是兔兔不是兔砸' '乌露斯拉'
#  'x_x' 'Kogami.' '略贵于宇宙' '我是鲁西西' '米饭（攒钱版）' 'momo（修行版）' '甜甜哈哈哈哈哈哈'
#  'Juan�Joanna' '黛西UK -Visa' 'Anki旗' '米饭爱喝咖啡' '梦殊' 'ssssgg' 'Kong'
#  '小魏同学向前冲～' '阿静静' '纯种妈宝女' '隔壁老王Will' 'icelanders' '再吃甜食是狗！' '小红薯闹钟'
#  '一颗草莓�' '老妖女士在大理��' '婕妤Nuyoah' '巴拉巴拉小魔仙�' '铁铁铁柱' '没故事的女同学�' 'Jim' '黏苞米粒粒'
#  'Simba' 'ATM 阿青' '边边儿' '企鹅吃喝' '我爱运动' 'Sww' 'Oiaoia' 'Lily喵喵喵喵' '马不可'
#  '� 激辣ゲキカラ' '蓬莱阁有百香果' '森屿琉璃' 'RDK羅迪想要咩咩咩' '暖阳慢行的微旅手札！' '虾还是白灼的好吃-' '晨曦'
#  '半盏流年' '小九6' 'Maleficent�' '德智瑕疵车' '水果就咸菜' '忘带船fare的周慕云' '戴榕' '靖哥哥' '雅文'
#  'Lady Ann' '内内小姐是手残' '孙艺暚' '亚马逊申诉小舟' '壹壹假期' 'Eva-樱涵' '郑郑今天睡醒了吗'
#  '�张小安吃饱没烦恼' '随机的一个名' '史迪仔' '淇淇QQ' '心芽护牙大使' '春末夏至' 'xinyi0816' '浅噗噗'
#  'sweet瓜' '柒柒游戏' 'Yun☁' 'kylin火' '是L是L' '触碰云彩' 'ChiChiLïüLiü' '花姑娘的碎碎念'
#  'Sherry珺' 'W_W' '饿了就睡' '夜夜失眠' '鱼在我这里' '中铁 能建 阅臻府' '疯狂小狗' '汪汪汪……芝麻'
#  '小红薯658C3FEE' '见山见海见自己' '轰轰轰hhh～toby～' 'ohlalayaya' '三文鱼吃吗✨' 'Felix'
#  '是好梦呀_' '瑶小梦的王国' 'Skye' 'MP&中轻 啊海' 'Oolivia_不是橄榄油' '关西狼家的女王大人'
#  'GiGi呀-thirteenzhong' '汽水风声' 'DIOR-Daisy黛西�' '小蚁路书' 'Miranda' '小野猫'
#  '十二圆蛋.psd' '踏破铁鞋旅游' '猫猫的探险人生' '一眼万年' 'Fanfanzi' '软软来吃' '漕河泾打工妹' '纳兰悠悠滴'
#  '武力慧' '猪又炖粉条' '烨雁(暂停蓝锁' '小红书0919' 'Lidyan' 'onetwothree' '✨✨✨' 'Annie呀�'
#  '妃无颜' '樂游 Transport�' '咕噜现在就出发' '旭旭宝贝' 'Cc' 'QUQ超级i的白羊♈' '鹿呦呦�' 'bulu'
#  '王考拉想存钱' '八喜是只小狸花呀' 'CarrotBanny' 'zoe' '云呢拿�' '步行穿过太阳系'
#  '家有兄弟俩Seven Eleven' '﹎|大美丽ご' '上邪' '什么呀' 'Double-拾贰' 'shine西柠' '喜悦儿'
#  '羽丘芽美D' '��加菲掉在花堆里���' 'zctooo' '今天吃什么' 'Jansky' 'Play Golf' '五七想吃鼠片'
#  '大小王沪漂' '丸子头手残家' '小小马儿' '☀li思媛Emily�' '重度洁癖患者J小姐' '巴菲贝蒂晴�' '六六三十六' '揣兜兜'
#  '就算是混子也要好好生活' '热心市民豆芽菜' '啊树。' 'Mia懿之' '雯雯' '晶晶酱871219' '�Feiiiiii�'
#  '作天作地活宝' '今天恰饭了吗' 'Viella～' 'MIYAKO宮子' 'Dister z�' '生活节点存档处'
#  '小红薯668DBD80' '饭darling�' '南海渔夫' 'nightya' 'Emily小土豆' 'JL.Liao' 'toki'
#  '√Z' '青怀' '计宝贝' '爱喝咖啡的吃货羊' '小师妹在水贝' 'axuami' '� 固力果 ✨' '芒芒甘露椰椰冻�' 'Lily'
#  '姗姗是33呀' '稳航' '白烦烦' 'A茶呀' 'Gia' '素曦（スーセイ）' '官官' '我是麦克，靠谱的麦克' '甜崽' '桔桔'
#  'cindysheep' '艾特Ara' 'zzzzzzzzzz0z' '元气阿怡' '就是这个小可爱呀' '�一只耳' '爱喝胡萝卜橙汁的猫'
#  '玖玖零_Amy' '不要私信我' '国韵到家' '风吹过的夏天' '多田大叔' 'jenniesen' '懂事的锦鲤' '菠萝�' '随心生活'
#  '0432 in 粤A' '小渔不在线' '金鱼豆豆' 'Kitty' '荔枝飞影' '呱呱乐必中40w茄' '陈CC' '佛光普赵女士'
#  '网瘾少女vera' 'Jun' 'mina' '雷震雨' '海岸通' '远望犹如' 'OCEAN先生' '小红薯5B6C85D8'
#  'Gloria' '无所不能的elaine' 'Ling-Mi' '小绿仔' '�李李Rylee�' '枫音是个小HR' '酸辣妞子' 'Xx'
#  'Mrs.Flora' '吉吉波' '丁小七' '咿呀' '海外取经僧' '恋与制作人' '小兔子滴麻麻' '沱江小虾' '九哥' '楚湘灵'
#  '莫可兮' '媛媛小花花' '是耿律呀' '宠妻狂魔' '克利丝留子学姐' '是曼达呀' '巨凯轮毂升级专营-小胡' 'Vvisa' '捶你哦'
#  '艾丽丝佳' '卷～卷起来' '次元计画' '铁丁君的保保历险记' 'Achoo' '贾克布' '休闲骑手' '克母鸡' 'qw' '乐溪'
#  'yinyin日常' '玲娜贝儿' '蕉下客�' '立水桥momo' '环梦启航-Lucas' 'xer' 'PSV_Hound街拍'
#  'Abby B' '是然然呀' 'aeg' '三纯烤奶皮' '大账薄' '杂糅混沌_' '�WJ20LS' 'Wade' '熊猫血女战士'
#  '识喵' '为了灿烂的明天努力装修！' '木子兮兮' 'Papergalgilmore' '冰糖胡芦儿甜�' '都海伊' '卡机嘛'
#  'amurhuu' 'sis小唐��' '巴塞尔' '小红薯66869291' '今天吃什么水果吖' '邝安潼小钢牙' '一只特立独行的摩羯'
#  '马靖泽' '�baby酱�' '造个房子' '伊宁主子' '超大悲冰美式' '起起Isabelle_' 'Ivy�' '是Iris阿'
#  '侃侃旧改' 'YuMo（孕晚期）' '权小红' 'Uuuuu' '一个秋秋' '学就完事模拟器' '山辉夜六道剑樱' '宋万里' 'Law8'
#  '青葙子Willa' '睡睡家关于BJD' 'happy' '赛博老顽童' '有趣的立早月亮' 'William Lee李軍君' '满心欢喜'
#  '哆啦a梦的口袋' 'Ashley' '戴伟同学' '高山常青' '甜妹_小薯条�' '三郎娱乐八卦631127' '上观新闻'
#  '签签qianvisa' '小鹿斑比迪士尼xlbb215' '想静静的吃土' '蔡蔡蔡团子' '囡囡�米国�' 'Jieyuuuuu'
#  '我爱新冰乐' '红豆豆豆的豆' '女侠已退休' '粥一芍' 'lily-lily' '奥特威' '温迪' '奶香小笼包（孕中）' '恩姆花园'
#  '瑞纳冰不要冰' 'Mandy' '不知道取什么名字' 'KimmmQ' '蜜桃罐子' '结尼' '幼稚园的可爱鬼' '晚安曾经'
#  '筱宝减肥日记' '千里之外' '�kelly' '晴天一朵云' '我是九九啊' '是吃掉一道彩虹哇' '张张的瑜伽日常' '特殊资产123五哥'
#  'Mr.Tao' '不搭' '大頭宝宝' '菜緒' '哥白尼虾球' '樊宣辰Xena' '点子彬(装修中)' 'Atlas' '萌萌哒萌总'
#  '南南北南南东' '九鱼图' '铭宇同学请客' '狐狸把图' '涵胖胖�' '潮' '红烧狮子头' '追风筝的懒猫' '长宁评估.'
#  '酸奶吃不完辣' '糖心蜜薯' '�溪猫猫' 'momo居民区' '一颗圆仔' '霓霓（硬装中）' 'dahema' '深蓝小林' '咕噜噜哒'
#  '一颗红豆，单挑全宇宙。' '小暖' '唐嘉艺阿' '澳洲野玫瑰rose' '默安fly' '阿拉伯伯机车装备的小苦力'
#  'Flipped小雨点儿' '壹心说情感' '肖蝴蝶' '小尾巴～' '罗伊.CZXu' '汉艺康石石' '曾经沧海' '闪闪发光�'
#  '多肉葡萄少冰少糖' '阿奶阿油就是奶油' '魔都街溜子' 'Anpanman减肥中' '小方块不方' '董到家' '理想国木匠'
#  '�Valley。' '蹦蹦跳跳' '小西瓜妹妹' '幸运的标准差' '周一一' '好奇怪' '钧钧有礼' 'A姗姗亲子游' '是颜颜呀'
#  '西西Zoe' '橙沐' '星爸爸热水师' '什么时候暴富' '薇薇公主' '轩豆豆' '请叫我公主殿下' '李荞伊' '歪歪在飞' '小柠檬�'
#  '瑜伽人白白' '小泡芙�' '双马尾来的' 'JinJin�����' '疯狂的柠檬�' 'Vin' '混世精灵Qiu' '米诺地尔用完了'
#  '西瓜红' '悦悦妈妈' '珠瑗毓润' '�糖糖' '困不困' '牛马东东' '虾球在魔都' '爱米多多' 'nannan' 'KELLY豆'
#  '小香鱼子酱' '蓝柿子' '李佳琪' '斑点熊' 'MIUMIU' '美涵啊' '鸭鸭' '✨小妖晶晶✨' '甜味崽子' 'FreYa_J'
#  '嘚嘚小阿姨' '安吉拉GG' '玲玲玲儿' '仔仔的认识' 'Marcolon马卡龙' '大猩猩也是小星星' 'HOT小面团' '轻松熊�'
#  'Eva_c11' '开心警官�' '-o-，' '上善若水#水瓶' '浮生未歇 \ue13c' '芋泥啵啵吻' '朝阳老公主' '居居'
#  '力力' 'crystal' 'Elva Wang' '别蹲了，这里都有' '在逃读博小帆' 'jasmi' "C'estunetulipe"
#  'Azzzzura' 'Olivia�' '小C走过高加索' '面包宝宝（俄语版）' '漂亮宝贝不干了' '想要吃不胖' '一百次心动'
#  '喜乐的心是良药' '牢骚太盛防肠断' '蘑菇' '早安明天' '贵' 'Klaus' '芝士草莓' 'ALDI奥乐齐' '伊卡洛斯'
#  '今天7什么' '�糖豆儿' '来口草莓�蛋糕�' 'Paranoia萌萌' '海边的小樱桃' 'Pika麻麻的小星空'
#  'BlancWhite Studio' '坐婴儿车漂移' '替大家退休' 'Essay辅导学姐' '图图咪今天吃什么' '�kiki酱'
#  '\ue10e杨六六不想1米78\ue10e' '甫林' 'Keep walking' 'Lin' 'bibibo' '慕雅森'
#  'Iris早九晚六版' '山上一枝梅' '闕生' '护s欧尼' '喂？' '小尔东CHEN' '十八不是吧']

# %%
df_filtered
# Out:
#        nickname                   user_id  \
# 23          虞小白  59e2b27895c9352c192d65aa
# 321       白白的牙呀  565b06ad03eb843907fe3958
# 641         暴小走  5769f2a8bd0da5767252afba
# 642         暴小走  5769f2a8bd0da5767252afba
# 720     Sis玩转上迪  5726d70e50c4b430e097f6d3
# ...         ...                       ...
# 304621    经济观察报  6019152c000000000101d309
# 304789       川叶  65e88b74000000000b03171f
# 305267   澳康达�郎飘  65a00d330000000022006073
# 305640   小芬芬在香港  582aaab96a6a693edf351822
# 305698     壹周文具  5ae735ef4eacab6dd6937b4e
#
#                                                   content  \
# 23      今年盒马工坊青团子有豆沙 巧克力 笋干菜 咸蛋黄流沙 咸蛋黄肉松5种口味\n本咸蛋黄星人只入...
# 321     一家味道味道很好的意大利菜�店铺装修很温馨，昏黄的灯光搭配各种有意思的物件，一进去就不想出来...
# 641     �北京水母湖潜水\n夏季忙碌的周末开始啦！恭喜取得PADI 青少年ow开放水域潜水员、打击海...
# 642     今天的自由潜课程，恭喜取得PADI基础自由潜水员、浮潜潜水员证书����！！        ...
# 720                              ➗断货很久的补货 要的斯～\n
# ...                                                   ...
# 304621  营销快讯\n6 月 28 日，骆驼携新发布的专业户外品牌喜马拉雅亮相 2024 上海 ISP...
# 304789                                             嘿嘿拿下来了
# 305267  22款 奔驰E300L 豪华版\n22年1月上牌 安全行驶 3.3万公里\n稀缺游艇蓝配色 ...
# 305640  好多东西都放过期了，不知道还有一箱\n要命啊！\n\t\n还有一箱香奈儿唇膏要称斤了！过期的...
# 305698  透明插页式相册和传统相册在外观和功能上有一些明显的区别。\n1. 外观：透明插页式相册采用透...
#
#                                                  tag_list  \
# 23                         青团;就是喜欢糯叽叽;咸蛋黄美食;春日食;盒马鲜生;热量测评
# 321     法餐;意大利菜;米其林餐厅探店;西餐;餐厅推荐;氛围感餐厅;宝藏餐厅分享;料理;全球吃喝小分...
# 641     潜水;水肺潜水;padi;PADI潜水;北京潜水;北京水母湖;padi潜水;PADIOW;o...
# 642     潜水课程;自由潜水;夏日运动;游泳健身;去哪儿;padi;padi潜水;北京长远潜水学校;P...
# 720       雪莉玫;达菲;达菲和朋友们;上海迪士尼;迪士尼周边;玲娜贝儿;护照夹;达菲雪莉玫;饼饼;olu
# ...                                                   ...
# 304621
# 304789                                              打工人日常
# 305267
# 305640
# 305698  相册;相册里的第一张照片;透明相册;插页式相册;相册本推荐;拓麻歌子;高一文具;文具好物推荐...
#
#                        title  \
# 23                     盒马青团�
# 321     打卡我的梦中情店� risotto专门店
# 641              青少年潜水证书get！
# 642                 自由潜课程来啦！
# 720         ➗迪士尼雪莉玫护照夹 雪莉玫护照
# ...                      ...
# 304621       骆驼推出新户外品牌「喜马拉雅」
# 304789              上班上到爱马仕了
# 305267      这么便宜的游艇蓝怎么就没人要呢？
# 305640           今日打扫�。。����
# 305698               透明插页式相册
#
#                                                      text  score keywords
# 23      盒马青团�今年盒马工坊青团子有豆沙 巧克力 笋干菜 咸蛋黄流沙 咸蛋黄肉松5种口味\n本咸蛋...      3     [盒马]
# 321     打卡我的梦中情店� risotto专门店一家味道味道很好的意大利菜�店铺装修很温馨，昏黄的灯...      3    [米其林]
# 641     青少年潜水证书get！�北京水母湖潜水\n夏季忙碌的周末开始啦！恭喜取得PADI 青少年ow...      3     [潜水]
# 642     自由潜课程来啦！今天的自由潜课程，恭喜取得PADI基础自由潜水员、浮潜潜水员证书����！！...      3     [潜水]
# 720     ➗迪士尼雪莉玫护照夹 雪莉玫护照➗断货很久的补货 要的斯～\n         雪莉玫;达菲...      3     [护照]
# ...                                                   ...    ...      ...
# 304621  骆驼推出新户外品牌「喜马拉雅」营销快讯\n6 月 28 日，骆驼携新发布的专业户外品牌喜马拉...      3     [滑雪]
# 304789                                上班上到爱马仕了嘿嘿拿下来了打工人日常      3    [爱马仕]
# 305267  这么便宜的游艇蓝怎么就没人要呢？22款 奔驰E300L 豪华版\n22年1月上牌 安全行驶 ...      3     [游艇]
# 305640  今日打扫�。。����好多东西都放过期了，不知道还有一箱\n要命啊！\n\t\n还有一箱香奈...      3    [香奈儿]
# 305698  透明插页式相册透明插页式相册和传统相册在外观和功能上有一些明显的区别。\n1. 外观：透明插...      3     [护照]
#
# [2511 rows x 8 columns]

# %%
# check single post with user id
user_id = '645a4c7e000000001002b9f0'
show_content_by_user_id(df_user, domain_content_whitelist, domain_content_blacklist, user_id)
# Out:
# *** whitelist matched:宝格丽[1]
# *** whitelist matched:香奈儿[1]
# score: (2, ['宝格丽', '香奈儿']), text: 种草小红人项链 925纯银 全套包装种草小红人项链
# 925纯银 全套包装
# 绝对是口碑团购产品，真的是超级无敌好看了！
# 经典百搭的款式
# 小红人不用多说 绝对是宝家最经典的款
# -年四季戴着都特别好看滴
# 露出好看的锁骨 有丢丢清冷的气质
# 女孩你可以不漂亮 但细节一定要完美
#  白宝格丽  署队长
# 日记 百搭项链 学生党首饰          冬天戴什么项链;学生党也买得起;宝格丽;小众项链;首饰就要blingbling;项链推荐;项链分享;宝格丽小红人慈善款项链;宝格丽BVLGARl小红人项链;宝格丽弹簧项链;宝格丽小蛮腰;宝格丽大蛮腰||bv小红人白金色弹簧项链 BVLGARI 宝格丽bv弹簧项链
# BVLGARI 宝格丽慈弹簧小红人项链
# 保色度极高 完全不用担心褪色，刻字非常的清楚 1:1
# 小红人项链经典款式 真正做到了经久不衰！
# 独特纯粹的螺旋造型象征着过去 现在和末来的和谐
# 相承
# 百搭是它，经典是它，你要相信我，这条项链是你最
# 值得收藏的项链之一[刻字清晰 ]独特纯粹的螺旋造型
# ＃项链推荐 ＃项链  ＃项链分享
# 丽小红人慈善款项链          宝格丽项链;宝格;宝格丽;宝格丽BVLGARI;宝格丽弹簧项链;项链;bvlgari;项链推荐;项链分享;项链就要blingbling;请把我推给大数据;大数据把我推||一眼爱上!coco crush萎格纹项链Chanel coco crush 系列K黄萎格项链 上身超美[哇1
# 简约的萎格设计不失高雅大气
# crush的萎格纹元素很经典，
# 一直很喜欢这种简约大
# 气又有细节的设计，不论是耳环，戒指，项链还是手
# 镯都让我心动市还是爱的迫降口女主同款，好看又
# 百搭        项链推荐;项链分享;coco;chanel项链;香奈儿项链;cococrush;chanel;请把我推给大数据;爱官方官方大大求热门||今天的美貌是香奶奶给的香奈儿包包耳环是貞的好戴 满满的细节
# 搭配小香的发绳真的太仙 聚会妥妥的吸引男神购        香奈儿;香奈儿包包;chanel包包;香奈儿耳饰;香奈儿包包耳饰;香奈儿cf;香奈儿woc;请把我推给大数据;爱官方官方大大求热门
